# %%
l=[1,4,7,9]
print(l)
# Out:
# [1, 4, 7, 9]

# %%
sum_l=sum(l)
print("sum",sum_l)
count_l=len(l)
print("count",count_l)
# Out:
# sum 21
# count 4

# %%
a=[14,42,17,19]
sum_a=sum(a)
print("sum",sum_a)
count_a=len(a)
print("count",count_a)
# Out:
# sum 92
# count 4

# %%
p=[12,36,15,23,45,63,65]
sum_p=sum(p)
print("sum",sum_p)
count_p=len(p)
print("count",count_p)
# Out:
# sum 259
# count 7

# %%
k=[23,89,12,63,86,15]
sum_k=sum(k)
print("sum",sum_k)
count_k=len(k)
print("count",count_k)
# Out:
# sum 288
# count 6

# %%
j=[56,25,36,15,45,78]
sum_j=sum(j)
print("sum",sum_j)
count_j=len(j)
print("count",count_j)
# Out:
# sum 255
# count 6

# %%
p=[24,73,56,28,19,18,17,34,71]
sum_p=sum(p)
print("sum",sum_p)
count_p=len(p)
print("count",count_p)
mean=sum_p/count_p
print("mean is",mean)
# Out:
# sum 340
# count 9
# mean is 37.77777777777778

# %%
q=[24,19,18,17,34,71]
sum_q=sum(q)
print("sum",sum_q)
count_q=len(q)
print("count",count_q)
mean=sum_q/count_q
print("mean is",mean)
# Out:
# sum 183
# count 6
# mean is 30.5
