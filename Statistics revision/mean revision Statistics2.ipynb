# %%
l=[1,4,7,9]
print(l)
# Out:
# [1, 4, 7, 9]

# %%
sum_l=sum(l)
print("sum",sum_l)
count_l=len(l)
print("count",count_l)
# Out:
# sum 21
# count 4

# %%
a=[14,42,17,19]
sum_a=sum(a)
print("sum",sum_a)
count_a=len(a)
print("count",count_a)
# Out:
# sum 92
# count 4

# %%
p=[12,36,15,23,45,63,65]
sum_p=sum(p)
print("sum",sum_p)
count_p=len(p)
print("count",count_p)
# Out:
# sum 259
# count 7

# %%
k=[23,89,12,63,86,15]
sum_k=sum(k)
print("sum",sum_k)
count_k=len(k)
print("count",count_k)
# Out:
# sum 288
# count 6

# %%
j=[56,25,36,15,45,78]
sum_j=sum(j)
print("sum",sum_j)
count_j=len(j)
print("count",count_j)
# Out:
# sum 255
# count 6

# %%
p=[24,73,56,28,19,18,17,34,71]
sum_p=sum(p)
print("sum",sum_p)
count_p=len(p)
print("count",count_p)
mean=sum_p/count_p
print("mean is",mean)
# Out:
# sum 340
# count 9
# mean is 37.77777777777778

# %%
q=[24,19,18,17,34,71]
sum_q=sum(q)
print("sum",sum_q)
count_q=len(q)
print("count",count_q)
mean=sum_q/count_q
print("mean is",mean)
# Out:
# sum 183
# count 6
# mean is 30.5

# %%
m=[23,45,78,9,6,45,89,22,56,55,66,26]
sum_m=sum(m)
print("sum",sum_m)
count_m=len(m)
print("count",count_m)
mean=sum_m/count_m
print("mean is",mean)
# Out:
# sum 520
# count 12
# mean is 43.333333333333336

# %%
s=[32,52,85,65,45,78,96,12,35,46,15,26,45,8,96,35,12,45,15,35,69,85,4,58,69,32,15,45,45,69,86,84,96,545,2121,55,12,12]
sum_s=sum(s)
print("sum",sum_s)
count_s=len(s)
print("count",count_s)
print("mean is",mean)
# Out:
# sum 4380
# count 38
# mean is 43.333333333333336

# %%
t=[5,2,6,4,8,5,9]
sum_t=sum(t)
print("sum",sum(t))
count_t=len(t)
print("count",count_t)
# Out:
# sum 39
# count 7

# %%
s=[3,6,4,8]
sum_s=sum(s)
print("sum",sum(s))
count_s=len(s)
print("count",count_s)
# Out:
# sum 21
# count 4

# %%
s=[3,6,4,8]
sum_s=sum(s)
print("sum",sum_s)
count_s=len(s)
print("count",count_s)
mean=sum_s/count_s
print("mean is",mean)
# Out:
# sum 21
# count 4
# mean is 5.25

# %%
F=[13,63,42,81]
sum_F=sum(F)
print("sum",sum_F)
count_F=len(F)
print("count",count_F)
mean=sum_F/count_F
print("mean is",mean)
# Out:
# sum 199
# count 4
# mean is 49.75
