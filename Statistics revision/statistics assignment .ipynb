# %%
#write python program to find the mean of a list numbers.
data=[12,15,25,16,14,18,45,47,7,18,13,12,23]
mean_manual=sum(data)/len(data)
print("mean_manua=",mean_manual)
# Out:
# mean_manua= 20.384615384615383

# %%
data=[12,15,25,16,14,18,45,47,7,18,13,12,23]
import statistics
mean_lib=statistics.mean(data)
print("mean_lib=",mean_lib)
# Out:
# mean_lib= 20.384615384615383
