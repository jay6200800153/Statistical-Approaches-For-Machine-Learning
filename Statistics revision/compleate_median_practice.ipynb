# %%
dataset=[1,4,7,9,11]
dataset.sort()
N=len(dataset)
if N%2==0:
    median=(dataset[N//2]+dataset[N//2-1])/2
else:
    median=dataset[N//2]
print(median)
# Out:
# 7

# %%
dataset=[56,56,23,2,45,56,98,12,4,565,12,565,155,25,322]
dataset.sort
N=len(dataset)
if N%2==0:
    median=(dataset[N//2]+[N//2-1])/2
else:
    median=dataset[N//2]
print(median)
# Out:
# 12

# %%
dataset=[45,12,45,36,65,47,85,96,12,45,75,69,83,56,45,78,25,63]
dataset.sort
N=len(dataset)
if N%2==0:
    median=(dataset[N//2]+dataset[N//2-1])/2
else:
    median=dataset[N//2]
print(median)
# Out:
# 28.5

# %%
k=[2,4,5,6,8,9,12,14,15,17,19]
print(k[0])
print(k[1])
print(k[2])
print(k[3])
print(k[4])
print(k[5])
print(k[6])
print(k[7])
print(k[8])
print(k[9])
print(k[10])
n=len(k)
midd_poss=n//2
print(midd_poss)
print(k[midd_poss])
# Out:
# 2
# 4
# 5
# 6
# 8
# 9
# 12
# 14
# 15
# 17
# 19
# 5
# 9

# %%
a=[45,68,69,65,65,5458,89,25,8,655,545,25,25,220,89]
print(a[1])
print(a[2])
a.sort
n=len(a)
if n%2==0:
    median=(a[n//2]+[n//2-1])/2
else:
    median=a[n//2]
print(median)
# Out:
# 68
# 69
# 25

# %%
k=[12,14,15,16,18,19,22,24,25,27,29,39,40,42,45,47,49]
print(k[0])
print(k[1])
print(k[2])
print(k[3])
print(k[4])
print(k[5])
print(k[6])
print(k[7])
print(k[8])
print(k[9])
print(k[10])
print(k[11])
print(k[12])
print(k[13])
print(k[14])
print(k[15])
print(k[16])
n=len(k)
midd_poss=n//2
print(midd_poss)
print(k[midd_poss])
# Out:
# 12
# 14
# 15
# 16
# 18
# 19
# 22
# 24
# 25
# 27
# 29
# 39
# 40
# 42
# 45
# 47
# 49
# 8
# 25

# %%
m=[12,14,15]
print(m[0])
print(m[1])
print(m[2])
n=len(m)
midd_poss=n//2
print(midd_poss)
print(m[midd_poss])
# Out:
# 12
# 14
# 15
# 1
# 14

# %%
N=[12,14,15,16,17]
print(N[0])
print(N[1])
print(N[2])
print(N[3])
print(N[4])
n=len(N)
midd_poss=n//2
print(midd_poss)
print(N[midd_poss])
# Out:
# 12
# 14
# 15
# 16
# 17
# 2
# 15

# %%
p=[12,14,15,16]
print(p[0])
print(p[1])
print(p[2])
print(p[3])
n=len(p)
middpos1,midposs2=n//2,n//2-1
print(p[middpos1],p[midposs2])
# Out:
# 12
# 14
# 15
# 16
# 15 14

# %%
Q=[12,14,15,16,18,19]
print(Q[0:])
n=len(Q)
midpos1,midpos2=n//2,n//2-1
print(Q[midpos1],Q[midpos2])
# Out:
# [12, 14, 15, 16, 18, 19]
# 16 15

# %%
R=[12,14,15,16,18,19,20,22]
print(R[0:])
n=len(R)
midpos1,midpos2=n//2,n//2-1
print(R[midpos1],R[midpos2])
# Out:
# [12, 14, 15, 16, 18, 19, 20, 22]
# 18 16

# %%
S=[12,14,15,16,18,19,20,22,24,27]
print(S[0:])
n=len(S)
midpos1,midpos2=n//2-1,n//2
print(S[midpos1],S[midpos2])
# Out:
# [12, 14, 15, 16, 18, 19, 20, 22, 24, 27]
# 18 19

# %%
cc
print(T[0:])
n=len(T)
if n%2==0:
    midpos1=n//2-1
    midpos2=n//2
    print(midpos1,midpos2)
    print(T[midpos1],T[midpos2])
else:
    midpos=n//2
    print(midpos)
    print(T[midpos])
# Out:
# [12, 14, 15, 16, 18, 19, 20, 22, 24, 27, 36, 78]
# 5 6
# 19 20

# %%
u=[12,14,15,16,18,19,20,22,24,27,36,78,79,80,81]
print(u[0:])
n=len(u)
if n%2==0:
    midpos1=n//2-1
    midpos2=n//2
    print(midpos1,midpos2)
    print(u[midpos1],u[midpos2])
else:
    midpos=n//2
    print("middle index is",midpos)
    print(u[midpos])
# Out:
# [12, 14, 15, 16, 18, 19, 20, 22, 24, 27, 36, 78, 79, 80, 81]
# middle index is 7
# 22

# %%
k=[50,60,42,45,86,236,56,85,48,79,632,569,516,86,226,5855,68552,655,4562,569856,85655,6652523,88855,8555,87755,525688,558755,88556,5556,55]
print(k[0:])
n=len(k)
if n%2==0:
   midpos1=n//2-1
   midpos2=n//2
   print(midpos1,midpos2)
   print(k[midpos1],k[midpos2])
else:
   midpos=n//2
   print("middle index is",midpos)
   print(k[midpos])
# Out:
# [50, 60, 42, 45, 86, 236, 56, 85, 48, 79, 632, 569, 516, 86, 226, 5855, 68552, 655, 4562, 569856, 85655, 6652523, 88855, 8555, 87755, 525688, 558755, 88556, 5556, 55]
# 14 15
# 226 5855

# %%
v=[12,14,15,16,18,19,20,22,24,27,36,78,79,80,81,82,87,89,90,95,98]
print("list is :",v[0:])
n=len(v)
print(n)
if n%2==0:
   midpos1=n//2-1
   midpos2=n//2
   print(midpos1,midpos2)
   print(v[midpos1],v[midpos2])
else:
   midpos=n//2
   print("middle index is",midpos)
   print(v[midpos])
# Out:
# list is : [12, 14, 15, 16, 18, 19, 20, 22, 24, 27, 36, 78, 79, 80, 81, 82, 87, 89, 90, 95, 98]
# 21
# middle index is 10
# 36

# %%
w=[2,4,5,6,8,9,10,22,24,27,36,48,59,80,81,82,87,89,90,95,98,109,110,111,116,118,119,227,228,229,230,235]
print("the list is :",w[0:])
n=len(w)
print(n)
if n%2==0:
    midpos1=n//2-1
    midpos2=n//2
    print("middle index is",midpos1,midpos2)
    print("middle index is",w[midpos1],w[midpos2])
else:
    midpos=n//2
    print("middle index is",midpos)
    print(w[midpos])
# Out:
# the list is : [2, 4, 5, 6, 8, 9, 10, 22, 24, 27, 36, 48, 59, 80, 81, 82, 87, 89, 90, 95, 98, 109, 110, 111, 116, 118, 119, 227, 228, 229, 230, 235]
# 32
# middle index is 15 16
# middle index is 82 87

# %%
w=[2,4,5,6,8,9,10,22]
print("The list is:",w[0:])
n=len(w)
print(n)
if n%2==0:
    midpos1=n//2-1
    midpos2=n//2
    print("middle index",midpos1,midpos2)
    print("middle index",w[midpos1],w[midpos2])
    median=(w[midpos1]+w[midpos2])/2
    print("median of dataset w is:",median)
else:
    midpos=n//2
    print("middle index is",midpos)
    print(w[midpos])
    median=w([midpos])
    print("median is",median)
# Out:
# The list is: [2, 4, 5, 6, 8, 9, 10, 22]
# 8
# middle index 3 4
# middle index 6 8
# median of dataset w is: 7.0

# %%
import numpy as np
data=[2, 4, 5, 6, 8, 9, 10, 22]
x=np.median(data)
print(x)
# Out:
# 7.0

# %%
v=[21,41,51,61,81,91,101,221,331,441,771,888]
v.sort()
n=len(v)
if n%2==0:
    midpos1=n//2-1
    midpos2=n//2
    median=(v[midpos1]+v[midpos2])/2
    print("median is",median)
else:
    median=n//2
    print("median is",median)
# Out:
# median is 96.0

# %%
w=[21,41,51,61]
w.sort()
n=len(w)
if n%2==0:
    midpos1=n//2-1
    midpos2=n//2
    median=(w[midpos1]+w[midpos2])/2
    print("median is",median)
else:
    median=n//2
    print("median is",median)
# Out:
# median is 46.0
